# %%
from data_processors import *
import toggl_api
from datetime import datetime as dt

pd.set_option('display.max_columns', None)

# Get the projects and time entries data from the Toggl API
projects = toggl_api.get_projects()
all_time_entries = toggl_api.get_all_time_entries()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from data_processors import *
#       2 import toggl_api
#       3 import pandas as pd
#
# File ~/Documents/GitHub/toggl-dashboard/data_processors.py:1
# ----> 1 import pandas as pd
#       2 import pytz
#       3 import json
#
# File ~/Documents/GitHub/toggl-dashboard/.venv/lib/python3.9/site-packages/pandas/__init__.py:138
#     120 from pandas.core.reshape.api import (
#     121     concat,
#     122     lreshape,
#    (...)
#     134     qcut,
#     135 )
#     137 from pandas import api, arrays, errors, io, plotting, tseries
# --> 138 from pandas import testing
#     139 from pandas.util._print_versions import show_versions
#     141 from pandas.io.api import (
#     142     # excel
#     143     ExcelFile,
#    (...)
#     171     read_spss,
#     172 )
#
# File ~/Documents/GitHub/toggl-dashboard/.venv/lib/python3.9/site-packages/pandas/testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File ~/Documents/GitHub/toggl-dashboard/.venv/lib/python3.9/site-packages/pandas/_testing/__init__.py:914
#     909     import pytest
#     911     return pytest.raises(expected_exception, match=None)
# --> 914 cython_table = pd.core.common._cython_table.items()
#     917 def get_cython_table_params(ndframe, func_names_and_expected):
#     918     """
#     919     Combine frame, functions from com._cython_table
#     920     keys and expected result.
#    (...)
#     932         List of three items (DataFrame, function, expected result)
#     933     """
#
# AttributeError: partially initialized module 'pandas' has no attribute 'core' (most likely due to a circular import)

# %%
#pd.DataFrame(all_time_entries).head()

# %%
#preprocess_slot_entrie(all_time_entries)

# %%
#preprocess_projects(projects)

# %%
#min_date_allowed=dt(2023, 1, 1)
#max_date_allowed=dt(2025, 12, 31)
#start_date = pd.to_datetime(min_date_allowed).tz_localize('UTC')
#end_date = pd.to_datetime(max_date_allowed).tz_localize('UTC')

process_data(projects, all_time_entries, start_date=None, end_date=None)
# Out:
#     slot_entrie_id                  slot_entrie_guid  slot_entrie_wid  \
# 0       3065685248  05f8108602cd06a3541a4789110fc03f          7464902
# 1       3065685599  7f425c8c8fd4bf04bbcf47a8940480a6          7464902
# 2       3065701953  b0506c43093e60922d9881f741a22c89          7464902
# 3       3065711298  bf2306761138dc4145d180656a19b268          7464902
# 4       3065794638  1626801c56c19950111bde0a7f4183bd          7464902
# ..             ...                               ...              ...
# 58      3074532962  9859c4ad27768ab3d91b4bf9a55ce8c5          7464902
# 59      3074579544  fe2836d0819e1a1fe82e5164a4fc9dbb          7464902
# 60      3074636517  e81597dc893ea116c7bed989143d71b3          7464902
# 61      3074717091  11b3e3c594d0a53c3dbe0f62b57add7f          7464902
# 62      3074832784  09bebce318b0b32b244c7c7e173d86ba          7464902
#
#     slot_entrie_billable         slot_entrie_start          slot_entrie_stop  \
# 0                   True 2023-07-28 08:49:53+00:00 2023-07-28 08:49:53+00:00
# 1                   True 2023-07-28 08:50:41+00:00 2023-07-28 09:01:53+00:00
# 2                   True 2023-07-28 09:02:46+00:00 2023-07-28 09:10:16+00:00
# 3                  False 2023-07-28 09:10:16+00:00 2023-07-28 09:37:35+00:00
# 4                  False 2023-07-28 10:21:21+00:00 2023-07-28 10:46:21+00:00
# ..                   ...                       ...                       ...
# 58                  True 2023-08-04 07:18:42+00:00 2023-08-04 07:40:42+00:00
# 59                  True 2023-08-04 07:55:43+00:00 2023-08-04 08:17:43+00:00
# 60                  True 2023-08-04 08:37:30+00:00 2023-08-04 08:59:30+00:00
# 61                 False 2023-08-04 09:40:40+00:00 2023-08-04 10:39:22+00:00
# 62                 False 2023-08-04 11:21:03+00:00 2023-08-04 13:38:56+00:00
#
#     slot_entrie_duration                                   slot_entrie_tags  \
# 0                    0.0  ['[TA] Formación / Investigación / Brain Storm...
# 1                   11.2  ['[TA] Formación / Investigación / Brain Storm...
# 2                    7.5  ['[TA] Formación / Investigación / Brain Storm...
# 3              27.316667                                    Otras etiquetas
# 4                   25.0                                    Otras etiquetas
# ..                   ...                                                ...
# 58                  22.0               ['[TA] Comunicación / Coordinación']
# 59                  22.0               ['[TA] Comunicación / Coordinación']
# 60                  22.0                                         ['[DI] 2']
# 61                  58.7                                    Otras etiquetas
# 62            137.883333                                    Otras etiquetas
#
#     slot_entrie_duronly            slot_entrie_at  slot_entrie_uid  \
# 0                  True 2023-07-28 08:50:24+00:00          9577449
# 1                  True 2023-07-28 09:01:53+00:00          9577449
# 2                  True 2023-07-28 09:10:17+00:00          9577449
# 3                  True 2023-07-28 09:37:36+00:00          9577449
# 4                  True 2023-07-28 10:46:23+00:00          9577449
# ..                  ...                       ...              ...
# 58                 True 2023-08-04 07:40:44+00:00          9577449
# 59                 True 2023-08-04 08:18:20+00:00          9577449
# 60                 True 2023-08-05 06:52:19+00:00          9577449
# 61                 True 2023-08-04 10:39:23+00:00          9577449
# 62                 True 2023-08-05 06:27:11+00:00          9577449
#
#    slot_entrie_pid                            slot_entrie_description  \
# 0             <NA>                                Otras descripciones
# 1        193974151                                              tirea
# 2        193974151                                Otras descripciones
# 3             <NA>  Merge con CLIENT BII y JURI -> isolation en co...
# 4             <NA>                                Otras descripciones
# ..             ...                                                ...
# 58       193974151                                Otras descripciones
# 59       194002072                                Otras descripciones
# 60       194002072                                Otras descripciones
# 61            <NA>                                Otras descripciones
# 62            <NA>                                Otras descripciones
#
#    slot_entrie_tags_DI                         slot_entrie_tags_TA  \
# 0                       Formación / Investigación / Brain Storming
# 1                       Formación / Investigación / Brain Storming
# 2                       Formación / Investigación / Brain Storming
# 3                 <NA>                                        <NA>
# 4                 <NA>                                        <NA>
# ..                 ...                                         ...
# 58                                     Comunicación / Coordinación
# 59                                     Comunicación / Coordinación
# 60                   2
# 61                <NA>                                        <NA>
# 62                <NA>                                        <NA>
#
#     slot_entrie_counter  slot_entrie_time_diff  slot_entrie_excess_time  \
# 0                     1                    0.0                     <NA>
# 1                     2                    0.8                     -0.8
# 2                     3              12.083333                -0.883333
# 3                     4                    7.5                      0.0
# 4                     5              71.083333               -43.766667
# ..                  ...                    ...                      ...
# 58                    1                    0.0                  -1180.4
# 59                    2              37.016667               -15.016667
# 60                    3              41.783333               -19.783333
# 61                    4              63.166667               -41.166667
# 62                    5             100.383333               -41.683333
#
#    project_id     project_name
# 0         NaN  Otros proyectos
# 1   193974151            TIREA
# 2   193974151            TIREA
# 3         NaN  Otros proyectos
# 4         NaN  Otros proyectos
# ..        ...              ...
# 58  193974151            TIREA
# 59  194002072      Corporativo
# 60  194002072      Corporativo
# 61        NaN  Otros proyectos
# 62        NaN  Otros proyectos
#
# [63 rows x 20 columns]
